# %% [markdown]
# # Import packages

# %%
import numpy as np
import os, sys, time, datetime, pickle, copy, random
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from midi2seq import piano2seq, random_piano, process_midi_seq
from torch.utils.data import DataLoader, TensorDataset
from model_base import * # ComposerBase, CriticBase

# %% [markdown]
# # Task 1

# %%
"""
#   (''Class "Critic" should be a subclass of the class CriticBase. You must use the exact class name.) 
#   You should implement a multi-layer (2 or 3 layers) LSTM model in this class. 
#   The Model (the score function) takes a sequence of envents as input and outputs a score judging 
#   whether the piano music corresponding to the sequence is good music or bad music. 
#   A function to generate random music is provided in the "midi2seq.py". 
#   Use the function to create a collection of random piano plays as examples of bad music. 
#   Use the piano plays in the downloaded data as example of good music. 
#   (You don't need to use all the downloaded data. A sufficiently large subset will be enough.) 
#   Train the model in this class using both the good and the bad examples.
"""
# Out:
# '\n#   (\'\'Class "Critic" should be a subclass of the class CriticBase. You must use the exact class name.) \n#   You should implement a multi-layer (2 or 3 layers) LSTM model in this class. \n#   The Model (the score function) takes a sequence of envents as input and outputs a score judging \n#   whether the piano music corresponding to the sequence is good music or bad music. \n#   A function to generate random music is provided in the "midi2seq.py". \n#   Use the function to create a collection of random piano plays as examples of bad music. \n#   Use the piano plays in the downloaded data as example of good music. \n#   (You don\'t need to use all the downloaded data. A sufficiently large subset will be enough.) \n#   Train the model in this class using both the good and the bad examples.\n'

# %% [markdown]
# ### Training Data

# %% [markdown]
# ### 1. Good piano music

# %%
# Test midi to sequence
seq01 = piano2seq('./maestro-v1.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi')
seq01.shape
# Out:
# (40777,)

# %%
seq01
# Out:
# array([355, 265, 368, ..., 259, 256, 190], dtype=int32)

# %%
seq02 = piano2seq('./maestro-v1.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi')
print(f"Shape: {seq02.shape}")
seq02
# Out:
# Shape: (32208,)
# array([355, 258, 256, ..., 184, 256, 161], dtype=int32)

# %%
seq03 = piano2seq('./maestro-v1.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.midi')
print(f"Shape: {seq03.shape}")
seq03
# Out:
# Shape: (17977,)
# array([315, 256, 375, ..., 212, 188, 185], dtype=int32)

# %%
good_music = process_midi_seq(all_midis=None, datadir='.', n=10000, maxlen=100)
print(f"Shape: {good_music.shape}")
# Out:
# Shape: (10022, 101)

# %%
good_music
# Out:
# array([[257, 354, 256, ..., 256, 363,  56],
#        [256, 368,  67, ..., 256, 197, 357],
#        [160, 256, 196, ..., 257, 256, 162],
#        ...,
#        [371,  63, 370, ...,  82, 375,  75],
#        [ 39, 372,  51, ...,  39, 374,  46],
#        [ 75, 256, 373, ..., 256, 357,  90]], dtype=int32)

# %% [markdown]
# ### 2. Bad music

# %%
random_piano
# Out:
# <function midi2seq.random_piano(n=100)>

# %%
import glob

all_midis = glob.glob('./maestro-v1.0.0/**/*.midi')
len(all_midis)
# Out:
# 1184

# %%
# generate 100 random piano music
bad_music_midi = []
for i in range(len(all_midis)):
    bad_music_midi.append(random_piano(n = 100))

# %%
bad_music = process_midi_seq(all_midis=bad_music_midi, datadir='.', n=10000, maxlen=100)
print(f"Shape: {bad_music.shape}")
# Out:
# Shape: (10007, 101)

# %%
bad_music
# Out:
# array([[257, 305, 256, ..., 256, 160, 273],
#        [229, 253, 267, ..., 256, 360,  92],
#        [256, 360,  49, ..., 169, 258, 256],
#        ...,
#        [206, 297, 256, ..., 223, 264, 233],
#        [ 10, 261, 256, ..., 268, 256, 368],
#        [233, 279, 256, ..., 275, 256, 186]], dtype=int32)

# %% [markdown]
# ### train model

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
# inputs
good_music = torch.tensor(good_music, dtype=torch.float32)
bad_music = torch.tensor(bad_music, dtype=torch.float32)
# labels, good music as 1 and bad music as 0
good_labels = torch.ones((len(good_music), 1))
bad_labels = torch.zeros((len(bad_music), 1))
# combine good and bad music
all_data = torch.cat([good_music, bad_music], dim=0)
all_labels = torch.cat([good_labels, bad_labels], dim=0)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, label_train, label_test = train_test_split(all_data, all_labels, test_size=0.2, random_state=42, shuffle=True) # split data

scaler = MinMaxScaler() # normalize data
features_train = scaler.fit_transform(features_train)
features_test = scaler.fit_transform(features_test)

print(f"Train shape: {features_train.shape, label_train.shape}")
print(f"Test shape: {features_test.shape, label_test.shape}")
# Out:
# Train shape: ((16023, 101), torch.Size([16023, 1]))
# Test shape: ((4006, 101), torch.Size([4006, 1]))

# %%
train_dataset = TensorDataset(torch.Tensor(features_train), torch.Tensor(label_train)) # convert to dataset
test_dataset = TensorDataset(torch.Tensor(features_test), torch.Tensor(label_test)) # convert to dataset

# %%
train_dataset[0]
# Out:
# (tensor([0.6755, 0.9868, 0.2243, 0.4855, 0.6772, 0.5608, 0.5172, 0.6852, 0.6772,
#          0.5620, 0.6887, 0.6737, 0.9894, 0.2354, 0.6903, 0.9735, 0.1530, 0.9709,
#          0.1852, 0.5092, 0.6772, 0.6772, 0.5224, 0.6799, 0.9921, 0.2480, 0.4908,
#          0.6789, 0.6772, 0.5741, 0.6947, 0.9868, 0.2540, 0.6807, 0.6772, 0.5858,
#          0.6984, 0.9578, 0.1296, 0.6755, 0.9841, 0.2566, 0.5910, 0.6825, 0.6755,
#          0.4683, 0.6825, 0.6719, 0.5952, 0.6958, 0.9789, 0.2672, 0.6755, 0.6042,
#          0.7222, 0.6755, 0.9657, 0.0952, 0.6799, 0.9604, 0.1266, 0.6868, 0.6772,
#          0.4339, 0.6745, 0.4656, 0.7467, 0.6772, 0.9657, 0.1583, 0.6745, 0.9762,
#          0.1715, 0.6772, 0.9815, 0.1900, 0.4960, 0.9684, 0.1504, 0.9709, 0.1263,
#          0.5092, 0.6772, 0.4881, 0.4644, 0.6772, 0.5291, 0.7704, 0.6719, 0.9789,
#          0.1693, 0.6825, 0.6755, 0.5079, 0.6984, 0.2037, 0.9761, 0.1706, 0.6825,
#          0.6772, 0.5106]),
#  tensor([1.]))

# %%
# convert to dataset
dataset = TensorDataset(all_data, all_labels)
dataloader = DataLoader(dataset, shuffle=True, batch_size=32)

# %%
for batch_idx, (data, target) in enumerate(dataloader):
    print(f"Batch: {batch_idx}, Data: {data.shape}, Target: {target.shape}")
# Out:
# Batch: 0, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 1, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 2, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 3, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 4, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 5, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 6, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 7, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 8, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 9, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 10, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 11, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 12, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 13, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 14, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 15, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 16, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 17, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 18, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 19, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 20, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 21, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 22, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 23, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 24, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 25, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 26, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 27, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 28, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 29, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 30, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 31, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 32, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 33, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 34, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 35, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 36, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 37, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 38, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 39, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 40, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 41, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 42, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 43, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 44, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 45, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 46, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 47, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 48, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 49, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 50, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 51, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 52, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 53, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 54, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 55, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 56, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 57, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 58, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 59, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 60, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 61, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 62, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 63, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 64, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 65, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 66, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 67, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 68, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 69, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 70, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 71, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 72, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 73, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 74, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 75, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 76, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 77, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 78, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 79, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 80, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 81, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 82, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 83, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 84, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 85, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 86, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 87, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 88, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 89, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 90, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 91, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 92, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 93, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 94, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 95, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 96, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 97, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 98, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 99, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 100, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 101, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 102, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 103, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 104, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 105, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 106, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 107, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 108, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 109, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 110, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 111, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 112, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 113, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 114, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 115, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 116, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 117, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 118, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 119, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 120, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 121, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 122, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 123, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 124, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 125, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 126, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 127, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 128, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 129, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 130, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 131, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 132, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 133, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 134, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 135, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 136, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 137, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 138, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 139, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 140, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 141, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 142, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 143, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 144, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 145, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 146, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 147, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 148, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 149, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 150, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 151, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 152, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 153, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 154, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 155, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 156, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 157, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 158, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 159, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 160, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 161, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 162, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 163, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 164, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 165, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 166, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 167, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 168, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 169, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 170, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 171, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 172, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 173, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 174, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 175, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 176, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 177, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 178, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 179, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 180, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 181, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 182, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 183, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 184, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 185, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 186, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 187, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 188, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 189, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 190, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 191, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 192, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 193, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 194, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 195, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 196, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 197, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 198, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 199, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 200, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 201, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 202, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 203, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 204, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 205, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 206, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 207, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 208, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 209, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 210, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 211, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 212, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 213, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 214, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 215, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 216, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 217, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 218, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 219, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 220, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 221, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 222, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 223, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 224, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 225, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 226, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 227, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 228, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 229, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 230, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 231, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 232, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 233, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 234, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 235, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 236, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 237, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 238, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 239, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 240, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 241, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 242, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 243, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 244, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 245, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 246, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 247, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 248, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 249, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 250, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 251, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 252, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 253, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 254, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 255, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 256, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 257, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 258, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 259, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 260, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 261, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 262, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 263, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 264, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 265, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 266, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 267, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 268, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 269, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 270, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 271, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 272, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 273, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 274, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 275, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 276, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 277, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 278, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 279, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 280, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 281, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 282, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 283, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 284, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 285, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 286, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 287, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 288, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 289, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 290, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 291, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 292, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 293, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 294, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 295, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 296, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 297, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 298, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 299, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 300, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 301, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 302, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 303, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 304, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 305, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 306, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 307, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 308, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 309, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 310, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 311, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 312, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 313, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 314, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 315, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 316, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 317, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 318, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 319, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 320, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 321, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 322, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 323, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 324, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 325, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 326, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 327, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 328, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 329, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 330, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 331, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 332, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 333, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 334, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 335, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 336, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 337, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 338, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 339, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 340, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 341, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 342, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 343, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 344, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 345, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 346, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 347, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 348, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 349, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 350, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 351, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 352, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 353, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 354, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 355, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 356, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 357, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 358, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 359, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 360, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 361, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 362, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 363, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 364, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 365, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 366, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 367, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 368, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 369, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 370, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 371, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 372, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 373, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 374, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 375, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 376, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 377, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 378, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 379, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 380, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 381, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 382, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 383, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 384, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 385, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 386, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 387, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 388, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 389, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 390, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 391, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 392, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 393, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 394, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 395, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 396, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 397, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 398, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 399, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 400, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 401, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 402, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 403, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 404, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 405, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 406, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 407, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 408, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 409, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 410, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 411, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 412, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 413, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 414, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 415, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 416, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 417, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 418, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 419, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 420, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 421, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 422, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 423, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 424, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 425, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 426, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 427, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 428, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 429, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 430, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 431, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 432, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 433, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 434, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 435, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 436, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 437, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 438, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 439, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 440, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 441, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 442, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 443, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 444, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 445, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 446, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 447, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 448, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 449, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 450, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 451, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 452, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 453, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 454, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 455, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 456, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 457, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 458, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 459, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 460, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 461, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 462, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 463, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 464, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 465, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 466, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 467, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 468, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 469, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 470, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 471, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 472, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 473, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 474, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 475, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 476, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 477, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 478, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 479, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 480, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 481, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 482, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 483, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 484, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 485, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 486, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 487, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 488, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 489, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 490, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 491, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 492, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 493, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 494, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 495, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 496, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 497, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 498, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 499, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 500, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 501, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 502, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 503, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 504, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 505, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 506, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 507, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 508, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 509, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 510, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 511, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 512, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 513, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 514, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 515, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 516, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 517, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 518, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 519, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 520, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 521, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 522, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 523, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 524, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 525, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 526, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 527, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 528, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 529, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 530, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 531, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 532, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 533, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 534, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 535, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 536, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 537, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 538, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 539, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 540, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 541, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 542, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 543, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 544, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 545, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 546, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 547, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 548, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 549, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 550, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 551, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 552, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 553, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 554, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 555, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 556, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 557, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 558, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 559, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 560, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 561, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 562, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 563, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 564, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 565, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 566, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 567, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 568, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 569, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 570, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 571, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 572, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 573, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 574, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 575, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 576, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 577, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 578, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 579, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 580, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 581, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 582, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 583, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 584, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 585, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 586, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 587, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 588, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 589, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 590, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 591, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 592, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 593, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 594, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 595, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 596, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 597, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 598, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 599, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 600, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 601, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 602, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 603, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 604, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 605, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 606, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 607, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 608, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 609, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 610, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 611, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 612, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 613, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 614, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 615, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 616, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 617, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 618, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 619, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 620, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 621, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 622, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 623, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 624, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 625, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 626, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 627, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 628, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 629, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 630, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 631, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 632, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 633, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 634, Data: torch.Size([32, 101]), Target: torch.Size([32, 1])
# Batch: 635, Data: torch.Size([21, 101]), Target: torch.Size([21, 1])

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch
from torch.autograd import Variable

from torch.utils.data import DataLoader, TensorDataset
from model_base import CriticBase

class Critic(nn.Module, CriticBase):
    def __init__(self, seq_length, num_classes=1, input_size=51, hidden_size=2, num_layers=1):
        super(Critic, self).__init__()
        self.num_classes = num_classes #number of classes
        self.num_layers = num_layers #number of layers
        self.input_size = input_size #input size
        self.hidden_size = hidden_size #hidden state
        self.seq_length = seq_length #sequence length

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first=True) #lstm
        self.fc_1 =  nn.Linear(hidden_size, 128) #fully connected 1
        self.fc = nn.Linear(128, num_classes) #fully connected last layer

        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #hidden state
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #internal state
        # Propagate input through LSTM
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) #lstm with input, hidden, and internal state
        hn = hn.view(-1, self.hidden_size) #reshaping the data for Dense layer next
        out = self.relu(hn)
        out = self.fc_1(out) #first Dense
        out = self.sigmoid(out) #relu
        out = self.fc(out) #Final Output
        return out


    def score(self,x):
        return(self.forward(x))

    def train_model(self, good_music_data, bad_music_data, epochs=10, lr=0.001):
        device = torch.device("cuda" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
        self.to(device)

        criterion = nn.BCELoss()
        optimizer = optim.Adam(self.parameters(), lr=lr)

        # Label good music as 1 and bad music as 0
        good_labels = torch.ones((len(good_music_data), 1))
        bad_labels = torch.zeros((len(bad_music_data), 1))

        all_data = torch.cat([good_music_data, bad_music_data], dim=0)
        all_labels = torch.cat([good_labels, bad_labels], dim=0)

        dataset = TensorDataset(all_data, all_labels)
        dataloader = DataLoader(dataset, shuffle=True, batch_size=32)

        print("Start training")
        running_loss = 0.0
        for epoch in range(epochs):
            for batch_idx, (data, target) in enumerate(dataloader):
                data, target = data.to(device), target.to(device)

                optimizer.zero_grad()
                outputs = self.forward(data)
                loss = criterion(outputs, target)
                loss.backward()
                optimizer.step()

            print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}")
        print("Finished training")

# %%
model = Critic(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, num_classes=1)

model.train_model(good_music_data=good_music, bad_music_data=bad_music, epochs=10, lr=0.001)
# Out:
# Start training
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 26 line 3
#       <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> model = Critic(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, num_classes=1)
# ----> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=2'>3</a> model.train_model(good_music_data=good_music, bad_music_data=bad_music, epochs=10, lr=0.001)
#
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 26 line 6
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=63'>64</a> data, target = data.to(device), target.to(device)
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=65'>66</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=66'>67</a> outputs = self.forward(data)
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=67'>68</a> loss = criterion(outputs, target)
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=68'>69</a> loss.backward()
#
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 26 line 3
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=28'>29</a> c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #internal state
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=29'>30</a> # Propagate input through LSTM
# ---> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=30'>31</a> output, (hn, cn) = self.lstm(x, (h_0, c_0)) #lstm with input, hidden, and internal state
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=31'>32</a> hn = hn.view(-1, self.hidden_size) #reshaping the data for Dense layer next
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X63sZmlsZQ%3D%3D?line=32'>33</a> out = self.relu(hn)
#
# File ~/miniconda3/envs/pianoGen/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/pianoGen/lib/python3.8/site-packages/torch/nn/modules/rnn.py:803, in LSTM.forward(self, input, hx)
#     800         if hx[0].dim() != 2 or hx[1].dim() != 2:
#     801             msg = ("For unbatched 2-D input, hx and cx should "
#     802                    f"also be 2-D but got ({hx[0].dim()}-D, {hx[1].dim()}-D) tensors")
# --> 803             raise RuntimeError(msg)
#     804         hx = (hx[0].unsqueeze(1), hx[1].unsqueeze(1))
#     806 # Each batch of the hidden state should match the input sequence that
#     807 # the user believes he/she is passing in.
#
# RuntimeError: For unbatched 2-D input, hx and cx should also be 2-D but got (3-D, 3-D) tensors

# %%
import torch.nn.functional as F

class Critic(nn.Module, CriticBase):
    def __init__(self, seq_length, hidden_size, num_layers=3, n_classes=1):
        super(Critic, self).__init__()
        self.seq_length = seq_length
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = n_classes
        self.lstm = nn.LSTM(input_size = self.seq_length, hidden_size = self.hidden_size, num_layers = self.num_layers, batch_first=True)
        self.fc = nn.Linear(self.hidden_size, self.hidden_size)
        #self.fc2 = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, x):
        # Initial state with shape: (batch_size, num_hiddens)
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_()

        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_()

        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))

        print(f"out: {out.shape}")
        
        out = self.fc(out[:, -1, :]) 

        return F.sigmoid(out)           # (batch_size, output_size)         
    
    def score(self,x):
        return(self.forward(x))

    def train_model(self, good_music_data, bad_music_data, epochs=10, lr=0.001):
        device = torch.device("cuda" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
        self.to(device)

        criterion = nn.BCELoss()
        optimizer = optim.Adam(self.parameters(), lr=lr)

        # Label good music as 1 and bad music as 0
        good_labels = torch.ones((len(good_music_data), 1))
        bad_labels = torch.zeros((len(bad_music_data), 1))

        all_data = torch.cat([good_music_data, bad_music_data], dim=0)
        all_labels = torch.cat([good_labels, bad_labels], dim=0)

        dataset = TensorDataset(all_data, all_labels)
        dataloader = DataLoader(dataset, shuffle=True, batch_size=32)

        print("Start training")
        running_loss = 0.0
        for epoch in range(epochs):
            for batch_idx, (data, target) in enumerate(dataloader):
                data, target = data.to(device), target.to(device)

                optimizer.zero_grad()
                outputs = self.forward(data)
                loss = criterion(outputs, target)
                loss.backward()
                optimizer.step()

            print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}")
        print("Finished training")
        
        torch.save(self.state_dict(), 'critic.pth')

# %%
model = Critic(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, n_classes=1)

model.train_model(good_music_data=good_music, bad_music_data=bad_music, epochs=10, lr=0.001)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> model = Critic(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, n_classes=1)
#       <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> model.train_model(good_music_data=good_music, bad_music_data=bad_music, epochs=10, lr=0.001)
#
# TypeError: __init__() got an unexpected keyword argument 'n_classes'

# %% [markdown]
# # Task 2

# %%
##*************************Task 2*********************#
#   (Class "Composer" should be a subclass of the class ComposerBase. You must use the exact class name.) 
#   You should implement a multi-layer (2 or 3 layers) LSTM model in this class. When the compose member 
#   function is called, it should return a sequence of events. Randomness is require in the implementation 
#   of the compose function such that each call to the function should generate a different sequence. 
#   The function "seq2piano" in "midi2seq.py" can be used to convert the sequence into a midi object, 
#   which can be written to a midi file and played on a computer. Train the model as a language model 
#   (autoregression) using the downloaded piano plays.

# %%
class Composer(nn.Module, ComposerBase):
    def __init__(self, seq_length, hidden_size, num_layers=3, n_classes=1):
        super(Composer, self).__init__()
        self.seq_length = seq_length # seq_length
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = n_classes

        self.lstm = nn.LSTM(input_size = self.seq_length, hidden_size = self.hidden_size, num_layers = self.num_layers, batch_first=True)
        self.fc1 = nn.Linear(self.hidden_size, self.hidden_size)
        self.fc2 = nn.Linear(self.hidden_size, self.n_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = F.relu(out)
        out = self.fc1(out)
        out = F.relu(out)
        out = self.fc2(out)
        return out
    
    def compose(self, seq_length=100):
        device = torch.device("cuda" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
        self.to(device)
        self.eval()

        # Generate random input
        input = torch.randint(0, 128, (1, seq_length, 1)).to(device)

        # Generate output
        output = self.forward(input)

        # Convert output to piano sequence
        output = output.cpu().detach().numpy()
        output = np.argmax(output, axis=2)
        output = output.reshape(-1)
        output = output.tolist()

        return output
    
    def train_model(self, good_music_data, epochs=10, lr=0.001):
        device = torch.device("cuda" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
        self.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(self.parameters(), lr=lr)

        dataset = TensorDataset(good_music_data)
        dataloader = DataLoader(dataset, shuffle=True, batch_size=32)

        print("Start training")
        running_loss = 0.0
        for epoch in range(epochs):
            for batch_idx, data in enumerate(dataloader):
                data = data.to(device)

                optimizer.zero_grad()
                outputs = self.forward(data)
                loss = criterion(outputs, data)
                loss.backward()
                optimizer.step()

            print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}")
        print("Finished training")

        torch.save(self.state_dict(), 'composer.pth')

# %%
composer = Composer(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, n_classes=128)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> composer = Composer(seq_length=all_data.shape[1], hidden_size=128, num_layers=3, n_classes=128)
#
# /Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb Cell 30 line 1
#       <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X56sZmlsZQ%3D%3D?line=8'>9</a> self.lstm = nn.LSTM(input_size = self.seq_length, hidden_size = self.hidden_size, num_layers = self.num_layers, batch_first=True)
#      <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X56sZmlsZQ%3D%3D?line=9'>10</a> self.fc1 = nn.Linear(self.hidden_size, self.hidden_size)
# ---> <a href='vscode-notebook-cell:/Users/gbemidebe/Documents/LSUCourses/Fall2023/CSC7343/homeworks/HW01/PianoGen/hw.ipynb#X56sZmlsZQ%3D%3D?line=10'>11</a> self.fc2 = nn.Linear(self.hidden_size, self.n_classes)
#
# File ~/miniconda3/envs/pianoGen/lib/python3.8/site-packages/torch/nn/modules/module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'Composer' object has no attribute 'n_classes'
